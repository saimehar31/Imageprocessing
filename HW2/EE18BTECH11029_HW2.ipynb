# %%
#question 1.1.1
import matplotlib.image as mpimg 
import matplotlib.pyplot as plt 
from numpy import asarray                                        
import numpy as np
import math
img = mpimg.imread('5.1.10.tiff')
#print (img.shape)
N=len(img);
M=len(img[0]);

#Initializing the DFT matrix
dft = 1j*np.zeros([len(img),len(img)]);

for u in range (len(img)):
    for v in range (len(img[0])):
        for i in range (len(img)):
            for j in range (len(img[0])):
                dft[u][v]=img[i][j]*np.exp(-2*np.pi*1j*(u*i/N + v*j/M));

#printing the values of DFT
print (dft)


#Initializing the IDFT matrix
idft = 1j*np.zeros([len(img),len(img)]);

for i in range (len(img)):
    for j in range(len(img[0])):
        for u in range (len(img)):
            for v in range (len(img[0])):
                idft[i][j]=1/(M*N) * dft[u][v]*np.exp(2*np.pi*1j*(u*i/N + v*j/M));
                
#printing the values of IDFT
print (idft)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-76e119dd868a> in <module>
#      15         for i in range (len(img)):
#      16             for j in range (len(img[0])):
# ---> 17                 dft[u][v]=img[i][j]*np.exp(-2*np.pi*1j*(u*i/N + v*j/M));
#      18
#      19 print (dft)
#
# KeyboardInterrupt:

# %%
#question 1.1.2
import matplotlib.image as mpimg 
import matplotlib.pyplot as plt 
from numpy import asarray                                        
import numpy as np
import math
img = mpimg.imread('5.1.10.tiff')
#print (img.shape)
N=len(img);
M=len(img[0]);

#initializing the values of DFT matrix
DFT = 1j*np.zeros([len(img),len(img)]);   

#printing the values of W matrix
W = 1j*np.zeros([len(img),len(img)]);

for u in range (len(img)):
    for v in range (len(img[0])):
        W[u][v]=np.exp(-1j*(2*np.pi/N) *(u*v));

DFT = np.dot(W,np.dot(img,W))

#printing the values of DFT
#print (DFT);

#initializing the values of IDFT matrix
IDFT = 1j*np.zeros([len(img),len(img)]);  
for u in range (len(img)):
    for v in range (len(img[0])):
        W[u][v]=np.exp(1j*(2*np.pi/N) *(u*v))/N;

IDFT = np.dot(W,np.dot(img,W))
      
#printing the values of IDFT
#print (IDFT);
# Out:
# [[ 9.20827100e+06     +0.j          5.51666173e+04 -49429.89740396j
#   -4.33907437e+04 -89249.89838328j ...  6.22171652e+04   -881.12459772j
#   -4.33907437e+04 +89249.89838327j  5.51666173e+04 +49429.89740395j]
#  [ 3.07510589e+04+161431.67439381j -3.02075463e+04  -9904.21091654j
#    9.67849134e+04 -25059.71651041j ...  5.53390293e+04 -12647.80882164j
#   -1.38686358e+05 +33321.26697355j  1.34983016e+05+112188.38580008j]
#  [-3.21631833e+04 -83947.0742466j   5.51903146e+04 -97768.47460001j
#    7.30421446e+04 -60409.11085818j ...  2.19434487e+04 -14209.87021705j
#    1.20319979e+03 -55873.40445823j -2.60409813e+05 -10718.91216646j]
#  ...
#  [-2.36778742e+04 -98727.38746518j  1.21094589e+05 -30587.23915373j
#    4.47321012e+04-123265.95255825j ...  5.65901329e+04  +5320.89617778j
#    1.12446902e+05 -11474.27669659j  6.56069342e+04 -20269.34104647j]
#  [-3.21631833e+04 +83947.07424659j -2.60409813e+05 +10718.91216644j
# ...

# %%
#question 1.1.1
import matplotlib.image as mpimg 
import matplotlib.pyplot as plt                                        
import numpy as np
import math
import cmath
img = mpimg.imread('5.1.10.tiff')
N=len(img);
M=len(img[0]);

#plt.imshow(img,cmap='gray')


#initalizing the DFT matrix
DFT = 1j*np.zeros([len(img),len(img)]);   

#intializing the W matrix
W = 1j*np.zeros([len(img),len(img)]);

for u in range (len(img)):
    for v in range (len(img[0])):
        W[u][v]=np.exp(-1j*(2*np.pi/N) *(u*v));
        
#finding the DFT matrix        
DFT = np.dot(W,np.dot(img,W))
#print (DFT);


#intializing the logDFT matrix
logDFT = 1j*np.zeros([len(img),len(img)]);  

for i in range (len(img)):
    for j in range (len(img[0])):
        logDFT[i][j]=np.log2(1 + DFT[i][j]);

#print (logDFT)

#finding the value of original DFT
magnitude = np.linalg.norm(np.abs(DFT));
#print (magnitude)

#finding the value of logarithmic DFT
magnitudelog = np.linalg.norm(np.abs(logDFT));
#print (magnitudelog)

#Finding th phase matrix
t=np.angle([DFT.imag,DFT.real])   
#print (t)



############################################################################################
#question 1.1.2
#intializing the central shift matrix

cenDFT = 1j*np.zeros([len(img),len(img)]);  
for i in range (len(img)):
    for j in range (len(img[0])):
        cenDFT[i][j]= ((-1)**(i+j)) * DFT[i][j];
        
#finding the value of magnitude
cenmagnitude = np.linalg.norm(np.abs(cenDFT));
#print (cenmagnitude)


###############################################################################################

#initalizing the DFT and IDFT matrices
DFT = 1j*np.zeros([len(img),len(img)]);
IDFT = 1j*np.full( ( len(img), len(img[0]) ) , 0) 

W = 1j*np.zeros([len(img),len(img)]);

for u in range (len(img)):
    for v in range (len(img[0])):
        W[u][v]=np.exp(-1j*(2*np.pi/N) *(u*v));

DFT = np.matmul(W,np.matmul(img,W))
        
for u in range (len(img)):
    for v in range (len(img[0])):
        W[u][v]=np.exp(1j*(2*np.pi/N) *(u*v))/(N);
        
IDFT = np.matmul(W,np.matmul(DFT,W))

#Proving the given statement
count=0;
for i in range (len(img)):
    for j in range (len(img[0])):
        if(img[i][j] - IDFT.real[i][j] >= 1):
            count=count+1;

if(count == 0):
    print ("Hence IDFT[DFT[I]] = I is verified ")
    
#print (IDFT.real)
            
######################################################################
# Out:
# [[[0.         3.14159265 3.14159265 ... 3.14159265 0.         0.        ]
#   [0.         3.14159265 3.14159265 ... 3.14159265 0.         0.        ]
#   [3.14159265 3.14159265 3.14159265 ... 3.14159265 3.14159265 3.14159265]
#   ...
#   [3.14159265 3.14159265 3.14159265 ... 0.         3.14159265 3.14159265]
#   [0.         0.         0.         ... 3.14159265 0.         0.        ]
#   [3.14159265 3.14159265 3.14159265 ... 0.         0.         0.        ]]
#
#  [[0.         0.         3.14159265 ... 0.         3.14159265 0.        ]
#   [0.         3.14159265 0.         ... 0.         3.14159265 0.        ]
#   [3.14159265 0.         0.         ... 0.         0.         3.14159265]
#   ...
#   [3.14159265 0.         0.         ... 0.         0.         0.        ]
#   [3.14159265 3.14159265 0.         ... 0.         0.         0.        ]
#   [0.         0.         3.14159265 ... 3.14159265 0.         3.14159265]]]
# Hence IDFT[DFT[I]] = I is verified

# %%
#question 2.1.1
import matplotlib.image as mpimg 
import matplotlib.pyplot as plt 
from numpy import asarray                                        
import numpy as np
import math
import cmath
I1 = mpimg.imread('5.1.10.tiff')

N1=len(I1);

#initializing 5*5 filter
I2= np.ones([5,5])/25

J = np.zeros([len(I1),len(I1[0])]);  

N=len(I1);
M=len(I1[0]);

for i in range (len(I1)):
    for j in range (len(I1[0])):
        sum=0;
        for p in range (len(I2)):
            for q in range (len(I2[0])):
                sum=sum + I1[(i-p)%N][(j-q)%M] * I2[p][q];
        J[i][j]=sum;
                
plt.imshow(J,cmap='gray')

# %%
#question 2.1.2
import matplotlib.image as mpimg 
import matplotlib.pyplot as plt 
from numpy import asarray                                        
import numpy as np
import math
import cmath
I1 = mpimg.imread('5.1.10.tiff')

#applying padding 
J = np.zeros([2*len(I1),2*len(I1)]); 
J2 = np.zeros([2*len(I1),2*len(I1)]); 
I2= np.ones([5,5])/25

K = np.zeros([len(I1),len(I1)]);

J[128:384,128:384] = I1

N=len(J);
M=len(J[0]);


for i in range (len(J)):
    for j in range (len(J[0])):
        sum=0;
        for p in range (len(I2)):
            for q in range (len(I2[0])):
                sum=sum + J[(i-p)%N][(j-q)%M] * I2[p][q];
        J2[i][j]=sum;

for i in range (128,384):
    for j in range (128,384):
        K[i-128][j-128]=J2[i][j];
        
plt.imshow(K,cmap='gray')

# %%
#question 2.1.3
import matplotlib.image as mpimg 
import matplotlib.pyplot as plt 
from numpy import asarray                                        
import numpy as np
import math
import cmath
I1 = mpimg.imread('5.1.10.tiff')
J = np.zeros([2*len(I1),2*len(I1)]); 
J2 = np.zeros([2*len(I1),2*len(I1)]); 
I2= np.ones([5,5])/25


#verifying that we can perform linear convolution using DFT of zero padded images
N=2*len(I1);
for i in range (len(I1)):
    for j in range (len(I1[0])):
        J[i][j]=I1[i][j]


for i in range (len(I2)):
    for j in range (len(I2[0])):
        J2[i][j]=I2[i][j]


#intialzing DFT matrix for I1 and finding the DFT
DFT1 = 1j*np.zeros([2*len(I1),2*len(I1)]);   

W1 = 1j*np.zeros([2*len(I1),2*len(I1)]);

for u in range (2*len(I1)):
    for v in range (2*len(I1[0])):
        W1[u][v]=np.exp(-1j*2*(np.pi/N) *(u*v))
        
DFT1 = np.dot(W1,np.dot(J,W1))


#intialzing DFT matrix for I2 and finding the DFT
DFT2 = 1j*np.zeros([2*len(I1),2*len(I1)]);   
W2 = 1j*np.zeros([2*len(I1),2*len(I1)]);

for u in range (2*len(I1)):
    for v in range (2*len(I1[0])):
        W2[u][v]=np.exp(-1j*2*(np.pi/N) *(u*v))
        
DFT2 = np.dot(W2,np.dot(J2,W2))
        

#multiplying both the matrices
DFT3 = 1j*np.zeros([2*len(I1),2*len(I1)]); 

DFT3 = np.multiply(DFT1,DFT2)
        

    
#applying the IDFT property
W3 = 1j*np.zeros([2*len(I1),2*len(I1)]);
IDFT = 1j*np.zeros([2*len(I1),2*len(I1)]);  

for u in range (2*len(I1)):
    for v in range (2*len(I1[0])):
        W3[u][v]=np.exp(1j*2*(np.pi/N) *(u*v))/N

IDFT = np.dot(W3,np.dot(DFT3,W3))
        
           
plt.imshow(IDFT.real[0:255,0:255],cmap='gray')

# %%
#question 3.1.1
import matplotlib.image as mpimg 
import matplotlib.pyplot as plt 
from numpy import asarray                                        
import numpy as np
import math
import cmath
I1 = mpimg.imread('5.1.10.tiff')
J = np.zeros([2*len(I1),2*len(I1)]); 
ran=np.random.normal(0,5,(256,256))

######################################################################
#for size 3*3

I2= np.ones([3,3])/9

for i in range (len(I1)):
    for j in range (len(I2)):
        J[i][j]=I1[i][j]+ran[i][j];
        
K = np.zeros([len(I1),len(I1)]);

J[128:384,128:384] = I1

N=len(J);
M=len(J[0]);
J2 = np.zeros([2*len(I1),2*len(I1)]); 

for i in range (len(J)):
    for j in range (len(J[0])):
        sum=0;
        for p in range (len(I2)):
            for q in range (len(I2[0])):
                sum=sum + J[(i-p)%N][(j-q)%M] * I2[p][q];
        J2[i][j]=sum;

for i in range (128,384):
    for j in range (128,384):
        K[i-128][j-128]=J2[i][j];


plt.subplot(1, 2, 1)
plt.imshow(K,cmap='gray')

############################################################################
#for size 5*5

I2= np.ones([5,5])/25

for i in range (len(I1)):
    for j in range (len(I2)):
        J[i][j]=I1[i][j]+ran[i][j];
        
K = np.zeros([len(I1),len(I1)]);

J[128:384,128:384] = I1

N=len(J);
M=len(J[0]);
J2 = np.zeros([2*len(I1),2*len(I1)]); 

for i in range (len(J)):
    for j in range (len(J[0])):
        sum=0;
        for p in range (len(I2)):
            for q in range (len(I2[0])):
                sum=sum + J[(i-p)%N][(j-q)%M] * I2[p][q];
        J2[i][j]=sum;

for i in range (128,384):
    for j in range (128,384):
        K[i-128][j-128]=J2[i][j];


plt.subplot(1, 2, 2)
plt.imshow(K,cmap='gray')


##############################################################################
#for size 7*7

I2= np.ones([7,7])/49

for i in range (len(I1)):
    for j in range (len(I2)):
        J[i][j]=I1[i][j]+ran[i][j];
        
K = np.zeros([len(I1),len(I1)]);

J[128:384,128:384] = I1

N=len(J);
M=len(J[0]);
J2 = np.zeros([2*len(I1),2*len(I1)]); 

for i in range (len(J)):
    for j in range (len(J[0])):
        sum=0;
        for p in range (len(I2)):
            for q in range (len(I2[0])):
                sum=sum + J[(i-p)%N][(j-q)%M] * I2[p][q];
        J2[i][j]=sum;

for i in range (128,384):
    for j in range (128,384):
        K[i-128][j-128]=J2[i][j];


plt.subplot(1, 2, 3)
plt.imshow(K,cmap='gray')

###############################################################################
#for size 9*9

I2= np.ones([9,9])/81

for i in range (len(I1)):
    for j in range (len(I2)):
        J[i][j]=I1[i][j]+ran[i][j];
        
K = np.zeros([len(I1),len(I1)]);

J[128:384,128:384] = I1

N=len(J);
M=len(J[0]);
J2 = np.zeros([2*len(I1),2*len(I1)]); 

for i in range (len(J)):
    for j in range (len(J[0])):
        sum=0;
        for p in range (len(I2)):
            for q in range (len(I2[0])):
                sum=sum + J[(i-p)%N][(j-q)%M] * I2[p][q];
        J2[i][j]=sum;

for i in range (128,384):
    for j in range (128,384):
        K[i-128][j-128]=J2[i][j];


plt.subplot(1, 2, 4)
plt.imshow(K,cmap='gray')

###############################################################################
#for size 11*11

I2= np.ones([11,11])/121

for i in range (len(I1)):
    for j in range (len(I2)):
        J[i][j]=I1[i][j]+ran[i][j];
        
K = np.zeros([len(I1),len(I1)]);

J[128:384,128:384] = I1

N=len(J);
M=len(J[0]);
J2 = np.zeros([2*len(I1),2*len(I1)]); 

for i in range (len(J)):
    for j in range (len(J[0])):
        sum=0;
        for p in range (len(I2)):
            for q in range (len(I2[0])):
                sum=sum + J[(i-p)%N][(j-q)%M] * I2[p][q];
        J2[i][j]=sum;

for i in range (128,384):
    for j in range (128,384):
        K[i-128][j-128]=J2[i][j];


plt.subplot(1, 2, 5)
plt.imshow(K,cmap='gray')

#####################################################################################
#for size 13*13

I2= np.ones([13,13])/169

for i in range (len(I1)):
    for j in range (len(I2)):
        J[i][j]=I1[i][j]+ran[i][j];
        
K = np.zeros([len(I1),len(I1)]);

J[128:384,128:384] = I1

N=len(J);
M=len(J[0]);
J2 = np.zeros([2*len(I1),2*len(I1)]); 

for i in range (len(J)):
    for j in range (len(J[0])):
        sum=0;
        for p in range (len(I2)):
            for q in range (len(I2[0])):
                sum=sum + J[(i-p)%N][(j-q)%M] * I2[p][q];
        J2[i][j]=sum;

for i in range (128,384):
    for j in range (128,384):
        K[i-128][j-128]=J2[i][j];


plt.subplot(1, 2, 6)
plt.imshow(K,cmap='gray')

###################################################################################
#for size 15*15

I2= np.ones([15,15])/225

for i in range (len(I1)):
    for j in range (len(I2)):
        J[i][j]=I1[i][j]+ran[i][j];
        
K = np.zeros([len(I1),len(I1)]);

J[128:384,128:384] = I1

N=len(J);
M=len(J[0]);
J2 = np.zeros([2*len(I1),2*len(I1)]); 

for i in range (len(J)):
    for j in range (len(J[0])):
        sum=0;
        for p in range (len(I2)):
            for q in range (len(I2[0])):
                sum=sum + J[(i-p)%N][(j-q)%M] * I2[p][q];
        J2[i][j]=sum;

for i in range (128,384):
    for j in range (128,384):
        K[i-128][j-128]=J2[i][j];


plt.subplot(1, 2, 7)
plt.imshow(K,cmap='gray')
# Out:
# "\n##############################################################################\n\nI2= np.ones([7,7])/49\n\nfor i in range (len(I1)):\n    for j in range (len(I2)):\n        J[i][j]=I1[i][j]+ran[i][j];\n        \nK = np.zeros([len(I1),len(I1)]);\n\nJ[128:384,128:384] = I1\n\nN=len(J);\nM=len(J[0]);\nJ2 = np.zeros([2*len(I1),2*len(I1)]); \n\nfor i in range (len(J)):\n    for j in range (len(J[0])):\n        sum=0;\n        for p in range (len(I2)):\n            for q in range (len(I2[0])):\n                sum=sum + J[(i-p)%N][(j-q)%M] * I2[p][q];\n        J2[i][j]=sum;\n\nfor i in range (128,384):\n    for j in range (128,384):\n        K[i-128][j-128]=J2[i][j];\n\n\nplt.subplot(1, 2, 3)\nplt.imshow(K,cmap='gray')\n\n###############################################################################\n\nI2= np.ones([9,9])/81\n\nfor i in range (len(I1)):\n    for j in range (len(I2)):\n        J[i][j]=I1[i][j]+ran[i][j];\n        \nK = np.zeros([len(I1),len(I1)]);\n\nJ[128:384,128:384] =
# ...

# %%
#question 3.1.2
import matplotlib.image as mpimg 
import matplotlib.pyplot as plt 
from numpy import asarray                                        
import numpy as np
import math
import cmath
I1 = mpimg.imread('5.1.10.tiff')
H= np.ones([5,5])
N=5;

#intializing the sigma
sa=np.arange(0.5,5,0.5);

sigma=0
for i in sa:
    sigma=sigma+0.5  #incrementing sigma by 0.5 each time
    for u in range (5):
        for v in range (5):    #applying gaussian filter
            H[u][v]=np.exp(-2*((np.pi)*sigma)*((np.pi)*sigma)*((u**2 + v**2)/(N*N)))

    W = np.ones([5,5])
    for u in range (5):
        for v in range (5):
            W[u][v]=np.exp(1j*2*(np.pi/N) *(u*v))/N

    IDFT = np.ones([5,5])
    IDFT = np.dot(W,np.dot(H,W))

    #print (IDFT)

    J = np.zeros([2*len(I1),2*len(I1)]); 
    ran=np.random.normal(0,5,(256,256))

    for i in range (len(I1)):
        for j in range (len(I2)):
            J[i][j]=I1[i][j]+ran[i][j]; #adding random noise to the image

    K = np.zeros([len(I1),len(I1)]);

    J[128:384,128:384] = I1

    N=len(J);
    M=len(J[0]);
    J2 = np.zeros([2*len(I1),2*len(I1)]); 

    for i in range (len(J)):
        for j in range (len(J[0])):
            sum=0;
            for p in range (len(I2)):
                for q in range (len(I2[0])):
                    sum=sum + J[(i-p)%N][(j-q)%M] * H[p][q];
            J2[i][j]=sum;

    for i in range (128,384):
        for j in range (128,384):
            K[i-128][j-128]=J2[i][j];


    plt.figure()
    plt.imshow(K,cmap='gray')
# Out:
# /home/saimehar/.local/lib/python3.6/site-packages/ipykernel_launcher.py:22: ComplexWarning: Casting complex values to real discards the imaginary part
